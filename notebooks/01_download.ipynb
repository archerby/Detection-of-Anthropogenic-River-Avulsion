# %% [markdown]
# # Data Download
#
# This notebook demonstrates how to download the raw Sentinel-2 data using the provided data loader.

# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))
from data_loader import download_sentinel_data

# Download to raw data directory
output_dir = "../data/raw"
download_sentinel_data(output_dir)
